# %%
# !pip install numpy
# !pip install matplotlib
# !pip install scipy
# !pip install soundfile
# Out:
# Requirement already satisfied: numpy in /Users/lionelarmanet/.pyenv/versions/3.12.0/envs/notebooks/lib/python3.12/site-packages (2.2.1)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: python -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in /Users/lionelarmanet/.pyenv/versions/3.12.0/envs/notebooks/lib/python3.12/site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/lionelarmanet/.pyenv/versions/3.12.0/envs/notebooks/lib/python3.12/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/lionelarmanet/.pyenv/versions/3.12.0/envs/notebooks/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/lionelarmanet/.pyenv/versions/3.12.0/envs/notebooks/lib/python3.12/site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/lionelarmanet/.pyenv/versions/3.12.0/envs/notebooks/lib/python3.12/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /Users/lionelarmanet/.pyenv/versions/3.12.0/envs/notebooks/lib/python3.12/site-packages (from matplotlib) (2.2.1)
# Requirement already satisfied: packaging>=20.0 in /Users/lionelarmanet/.pyenv/versions/3.12.0/envs/notebooks/lib/python3.12/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/lionelarmanet/.pyenv/versions/3.12.0/envs/notebooks/lib/python3.12/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/lionelarmanet/.pyenv/versions/3.12.0/envs/notebooks/lib/python3.12/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/lionelarmanet/.pyenv/versions/3.12.0/envs/notebooks/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/lionelarmanet/.pyenv/versions/3.12.0/envs/notebooks/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: python -m pip install --upgrade pip
# Requirement already satisfied: scipy in /Users/lionelarmanet/.pyenv/versions/3.12.0/envs/notebooks/lib/python3.12/site-packages (1.14.1)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in /Users/lionelarmanet/.pyenv/versions/3.12.0/envs/notebooks/lib/python3.12/site-packages (from scipy) (2.2.1)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: python -m pip install --upgrade pip
# Requirement already satisfied: soundfile in /Users/lionelarmanet/.pyenv/versions/3.12.0/envs/notebooks/lib/python3.12/site-packages (0.13.0)
# Requirement already satisfied: cffi>=1.0 in /Users/lionelarmanet/.pyenv/versions/3.12.0/envs/notebooks/lib/python3.12/site-packages (from soundfile) (1.17.1)
# Requirement already satisfied: numpy in /Users/lionelarmanet/.pyenv/versions/3.12.0/envs/notebooks/lib/python3.12/site-packages (from soundfile) (2.2.1)
# Requirement already satisfied: pycparser in /Users/lionelarmanet/.pyenv/versions/3.12.0/envs/notebooks/lib/python3.12/site-packages (from cffi>=1.0->soundfile) (2.22)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: python -m pip install --upgrade pip

# %%
import numpy as np
import matplotlib.pyplot as plt

def square_wave(frequency, duration, sample_rate, harmonics=10):
    t = np.linspace(0, duration, int(sample_rate * duration), endpoint=False)
    wave = np.zeros_like(t)
    
    for n in range(1, harmonics * 2, 2):  # Harmoniques impaires
        wave += (1 / n) * np.sin(2 * np.pi * n * frequency * t)
    
    wave *= 4 / np.pi  # Normalisation
    return t, 0.5 * wave

frequency = 440  # Base note frequency in Hz (A4)
duration = 1.0   # Duration
sample_rate = 44100  # Sample Rate in Hz

t, wave = square_wave(frequency, duration, sample_rate)

# %%
plt.plot(t[:1000], wave[:1000])  # Afficher seulement 1000 échantillons
plt.title("Square sine")
plt.xlabel("Time)")
plt.ylabel("Amplitude")
plt.grid()
plt.show()

# %%
from scipy.io.wavfile import write

# wave = 16 bits encoding
wave_int16 = np.int16(wave * 32767)

write("sine_wave.wav", sample_rate, wave_int16)

# %%
from IPython.display import Audio
Audio("sine_wave.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
